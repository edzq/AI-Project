# %%
import pickle
import torch
import nltk
from nltk import word_tokenize, pos_tag
from sklearn.model_selection import train_test_split
#import pycrfsuite
import os, os.path, sys
import glob
from xml.etree import ElementTree
import numpy as np
from sklearn.metrics import classification_report

# %%
X, y, X_pids = pickle.load(open("ml_datasetname_inputs_flv0.p", "rb"))

# %%
type(X)
# Out:
# list

# %%
X[0][0]
# Out:
# ','

# %%
y[0][0]
# Out:
# 'O'

# %%
X_pids
# Out:
# [204950407,
#  204950407,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802619,
#  214802675,
#  214802675,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
#  2554264,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1)

# %%
print(len(set(np.concatenate(y_train).ravel())), len(set(np.concatenate(y_test).ravel())), len(set(np.concatenate(y_val).ravel())))
# Out:
# 3 3 3

# %%
print(len(np.concatenate(y_train).ravel()), len(np.concatenate(X_train).ravel()))
# Out:
# 9431025 9431025

# %%
len(X_train)
# Out:
# 126111

# %%
set(np.concatenate(y_train).ravel())
# Out:
# {'B', 'I', 'O'}

# %%
set(np.concatenate(y_test).ravel())
# Out:
# {'B', 'I', 'O'}

# %%
set(np.concatenate(y_val).ravel())
# Out:
# {'B', 'I', 'O'}

# %%
max(X_val, key=len)
# Out:
# ['lines',
#  'in',
#  'Corn',
#  'Leaf',
#  'Blight',
#  'and',
#  'spots',
#  'in',
#  'Tomato',
#  'Bacterial',
#  'Spots',
#  ')',
#  '.',
#  'The',
#  'network',
#  'even',
#  'learns',
#  'the',
#  'shape',
#  'of',
#  'the',
#  'leaf',
#  '(',
#  'shown',
#  'in',
#  'second',
#  'row',
#  'of',
#  'Figure',
#  '4',
#  ')',
#  'to',
#  'help',
#  'it',
#  'distinguish',
#  'between',
#  'species',
#  '.',
#  'As',
#  'predicted',
#  ',',
#  'the',
#  'results',
#  'in',
#  'Table',
#  '1',
#  'clearly',
#  'shows',
#  'that',
#  'real',
#  'case',
#  'scenarios',
#  'have',
#  'low',
#  'accuracy',
#  'when',
#  'processed',
#  'initially',
#  'with',
#  'ImageNet',
#  'or',
#  'PlantVillage',
#  '.',
#  'Also',
#  ',',
#  'Table',
#  '1',
#  'and',
#  'Table',
#  '2',
#  'clearly',
#  'shows',
#  'low',
#  'accuracy',
#  'achieved']

# %%
f = open("train.txt", "w", encoding="utf-8")

i = 0
count = 1
if X_train[0][0].encode("ascii", "ignore").decode():
    f.write(X_train[0][0].encode("ascii", "ignore").decode()+" "+y_train[0][0])
for xi, yi in zip(X_train[0],y_train[0]):
    if i == 0:
        i += 1
        continue
    if xi.encode("ascii", "ignore").decode():
        f.write('\n'+xi.encode("ascii", "ignore").decode()+" "+yi)
i = 0
for xi, yi in zip(X_train,y_train):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        if xii.encode("ascii", "ignore").decode():
            f.write('\n'+xii.encode("ascii", "ignore").decode()+" "+yii)
    count += 1
f.write("\n")
print(count)
f.close()
# Out:
# 126111

# %%
f = open("dev.txt", "w", encoding="utf-8")

i = 0
if X_val[0][0].encode("ascii", "ignore").decode():
    f.write(X_val[0][0].encode("ascii", "ignore").decode()+" "+y_val[0][0])
for xi, yi in zip(X_val[0],y_val[0]):
    if i == 0:
        i += 1
        continue
    if xii.encode("ascii", "ignore").decode():
        f.write('\n'+xi.encode("ascii", "ignore").decode()+" "+yi)
i = 0
for xi, yi in zip(X_val,y_val):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        if xii.encode("ascii", "ignore").decode():
            f.write('\n'+xii.encode("ascii", "ignore").decode()+" "+yii)
f.write("\n")
f.close()

# %%
f = open("test.txt", "w", encoding="utf-8")

i = 0
if X_test[0][0].encode("ascii", "ignore").decode():
    f.write(X_test[0][0].encode("ascii", "ignore").decode()+" "+y_test[0][0])
for xi, yi in zip(X_test[0],y_test[0]):
    if i == 0:
        i += 1
        continue
    if xii.encode("ascii", "ignore").decode():
        f.write('\n'+xi.encode("ascii", "ignore").decode()+" "+yi)
i = 0
for xi, yi in zip(X_test,y_test):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        if xii.encode("ascii", "ignore").decode():
            f.write('\n'+xii.encode("ascii", "ignore").decode()+" "+yii)
f.write("\n")
f.close()

# %% [markdown]
# ### 后面都可以不用看
#
# Some stupid testing stuff

# %%
# read file
f = open("train.txt", "r", encoding="utf-8")

Lines = f.readlines()

count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))
f.close()
# Out:
# Line1: EU B-ORG
# Line2: rejects O
# Line3: German B-MISC
# Line4: call O
# Line5: to O
# Line6: boycott O
# Line7: British B-MISC
# Line8: lamb O
# Line9: . O
# Line10:
# Line11: Peter B-PER
# Line12: Blackburn I-PER
# Line13:
# Line14: BRUSSELS B-LOC
# Line15: 1996-08-22 O
# Line16:
# Line17: The O
# Line18: European B-ORG
# Line19: Commission I-ORG
# Line20: said O
# Line21: on O
# Line22: Thursday O
# Line23: it O
# Line24: disagreed O
# Line25: with O
# Line26: German B-MISC
# Line27: advice O
# Line28: to O
# Line29: consumers O
# Line30: to O
# Line31: shun O
# Line32: British B-MISC
# Line33: lamb O
# Line34: until O
# Line35: scientists O
# Line36: determine O
# Line37: whether O
# Line38: mad O
# Line39: cow O
# Line40: disease O
# Line41: can O
# Line42: be O
# Line43: transmitted O
# Line44: to O
# Line45: sheep O
# Line46: . O
# Line47:
# Line48: Germany B-LOC
# Line49: 's O
# Line50: representative O
# Line51: to O
# Line52: the O
# Line53: European B-ORG
# ...

# %%
f = open("YourData/train.txt", "r", encoding="utf-8")

Lines = f.readlines()

print(len(Lines))

"""
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))
"""
f.close()
# Out:
# 9557135

# %%
f = open("train.txt", "w", encoding="utf-8")

i = 0
f.write(X_train[0][0]+" "+y_train[0][0])
for xi, yi in zip(X_train[0],y_train[0]):
    if i == 0:
        i += 1
        continue
    f.write('\n'+xi+" "+yi)
i = 0
count = 0
for xi, yi in zip(X_train,y_train):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        f.write('\n'+xii+" "+yii)
    if count >= 10:
        break
    count += 1
f.close()

# %%
f = open("dev.txt", "w", encoding="utf-8")

i = 0
f.write(X_val[0][0]+" "+y_val[0][0])
for xi, yi in zip(X_val[0],y_val[0]):
    if i == 0:
        i += 1
        continue
    f.write('\n'+xi+" "+yi)
i = 0
count = 0
for xi, yi in zip(X_val,y_val):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        f.write('\n'+xii+" "+yii)
    if count >= 10:
        break
    count += 1
f.close()

# %%
f = open("test.txt", "w", encoding="utf-8")

i = 0
f.write(X_test[0][0]+" "+y_test[0][0])
for xi, yi in zip(X_test[0],y_test[0]):
    if i == 0:
        i += 1
        continue
    f.write('\n'+xi+" "+yi)
i = 0
count = 0
for xi, yi in zip(X_test,y_test):
    if i == 0:
        i += 1
        continue
    f.write("\n")
    for xii, yii in zip(xi, yi):
        f.write('\n'+xii+" "+yii)
    if count >= 10:
        break
    count += 1
f.close()

# %%
sl = []
sl.append("a")
sl.append("b")
sl.append("c")
sll = []
sll.append(sl)
sll
# Out:
# [['a', 'b', 'c']]

# %%
f = open("YourData/train.txt", "r", encoding="utf-8", errors ='replace')

Lines = f.readlines()

sentences = []
labels = []
temp_sentence = []
temp_label = []

count = 0

nonascii = bytearray(range(0x80, 0x100))

for line in Lines:
    if line == "\n":
        sentences.append(temp_sentence)
        temp_sentence = []
        labels.append(temp_label)
        temp_label = []
        count+=1
    else:
        temp_sentence.append(line.split(" ")[0].encode("ascii", "ignore").decode("cp1251")) 
        temp_label.append(line.split(" ")[1])
sentences.append(temp_sentence)
labels.append(temp_label)
count+=1
f.close()

# %%
count
# Out:
# 126111

# %%
print(len(sentences[1328]))
# Out:
# 75

# %%
sentences[1327]
# Out:
# ['relevant',
#  'answer',
#  'to',
#  'a',
#  'factoid',
#  'question',
#  'from',
#  'candidate',
#  'answers',
#  '.',
#  'The',
#  'empirical',
#  'results',
#  'demonstrate',
#  'the',
#  'superiority',
#  'of',
#  'our',
#  'proposed',
#  'model',
#  ',',
#  'which',
#  'achieve',
#  'state-of-the-art',
#  'performance',
#  'for',
#  'TrecQA',
#  'raw',
#  '(',
#  'M.',
#  'Wang',
#  ',',
#  'Smith',
#  ',',
#  '&',
#  'Mitamura',
#  ',',
#  '2007',
#  ')',
#  ',',
#  'TrecQA',
#  'clean',
#  '(',
#  'Z.',
#  'Wang',
#  '&',
#  'Ittycheriah',
#  ',',
#  '2015',
#  ')',
#  'and',
#  'WikiQA',
#  '(',
#  'Y.',
#  'Yang',
#  ',',
#  'Yih',
#  ',',
#  '&',
#  'Meek',
#  ',',
#  '2015',
#  ')',
#  'datasets',
#  '.',
#  'The',
#  'contribution',
#  'of',
#  'this',
#  'research',
#  'paper',
#  'includes',
#  ':',
#  '',
#  'We']

# %%
words=['relevant', 'answer', 'to', 'a', 'factoid', 'question', 'from', 'candidate', 'answers', '.', 'The', 'empirical', 'results', 
       'demonstrate', 'the', 'superiority', 'of', 'our', 'proposed', 'model', ',', 'which', 'achieve', 'state-of-the-art', 'performance',
       'for', 'TrecQA', 'raw', '(', 'M.', 'Wang', ',', 'Smith', ',', '&', 'Mitamura', ',', '2007', ')', ',', 'TrecQA', 'clean', '(', 'Z.'
       , 'Wang', '&', 'Ittycheriah', ',', '2015', ')', 'and', 'WikiQA', '(', 'Y.', 'Yang', ',', 'Yih', ',', '&', 'Meek', ',', '2015', ')'
       , 'datasets', '.', 'The', 'contribution', 'of', 'this', 'research', 'paper', 'includes', ':', '\uf0b7', 'We']
ori_words=['relevant', 'answer', 'to', 'a', 'factoid', 'question', 'from', 'candidate', 'answers', '.', 'The', 'empirical', 'results', 
           'demonstrate', 'the', 'superiority', 'of', 'our', 'proposed', 'model', ',', 'which', 'achieve', 'state-of-the-art',
           'performance', 'for', 'TrecQA', 'raw', '(', 'M.', 'Wang', ',', 'Smith', ',', '&', 'Mitamura', ',', '2007', ')', ',',
           'TrecQA', 'clean', '(', 'Z.', 'Wang', '&', 'Ittycheriah', ',', '2015', ')', 'and', 'WikiQA', '(', 'Y.', 'Yang', ',', 'Yih', 
           ',', '&', 'Meek', ',', '2015', ')', 'datasets', '.', 'The', 'contribution', 'of', 'this', 'research', 'paper', 'includes', 
           ':', '\uf0b7', 'We']
labels=['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 
        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 
        'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
print(len(words), len(ori_words), len(labels))
# Out:
# 75 75 75

# %%
with open("YourData/train.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()
with open("YourData/train_v1.txt", "w", encoding="utf-8") as f:
    for line in lines:
        if line.split(" ")[0] != "\uf0b7":
            f.write(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12224/2622801778.py in <module>
# ----> 1 with open("data/YourData/train.txt", "r", encoding="utf-8") as f:
#       2     lines = f.readlines()
#       3 with open("data/YourData/train_v1.txt", "w", encoding="utf-8") as f:
#       4     for line in lines:
#       5         if line.split(" ")[0] != "\uf0b7":
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/YourData/train.txt'

# %%
sentences[3095]

# %%
a = '\uf0b7'
a.decode('cp1251').encode('utf8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12224/910689406.py in <module>
#       1 a = '\uf0b7'
# ----> 2 a.decode('cp1251').encode('utf8')
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
b'\uf0b7'.decode('cp1252')
# Out:
# 'uf0b7'
